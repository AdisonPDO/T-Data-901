# %%
import pandas as pd


pd.read_csv('./Liquor_Sales.csv')
# Out:
# /var/folders/7m/_y3b95f13bdbg_xvnwp6ryd80000gn/T/ipykernel_41485/2932705846.py:4: DtypeWarning: Columns (6,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv('./Liquor_Sales.csv')
#          Invoice/Item Number        Date  Store Number  \
# 0               S24127700024  02/19/2015          3678
# 1               S15066200002  10/10/2013          2633
# 2               S19323500030  06/03/2014          2607
# 3               S23334500013  01/06/2015          4810
# 4               S09742200010  12/27/2012          4025
# ...                      ...         ...           ...
# 19666758        S10600200004  02/13/2013          3864
# 19666759        S23597800012  01/21/2015          5065
# 19666760        S29278700041  11/24/2015          3400
# 19666761        S04908000004  04/05/2012          2579
# 19666762        S09763500040  12/28/2012          4265
#
#                                     Store Name                   Address  \
# ...

# %%
import duckdb as ddb

con = ddb.connect("my-working-database.db")
con.execute("""CREATE TABLE liquor AS (SELECT * FROM read_csv_auto('Liquor_Sales.csv', ALL_VARCHAR=1))""")
con.execute("SELECT * FROM liquor")
con.close()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
